# %%
pip --version
# Out:
# pip 23.2.1 from C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pip (python 3.9)
#
# Note: you may need to restart the kernel to use updated packages.
